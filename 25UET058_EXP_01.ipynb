# %%
print("Hello world")
# Out:
# hello world

# %%
name = "OMKAR"
age ="19"
college ="DKTE"
print(f"Hello my name is {name},and my age is {age},i am stduying in {college}")
# Out:
# Hello my name is OMKAR,and my age is 19,i am stduying in DKTE

# %%
print("my", "name",  "OMKAR", sep =" #")
# Out:
# my #name #OMKAR

# %%
Name =input ("Enter your name = ")
print("My name is",name)
print(type(name))
# Out:
# Enter your name = OMKAR
# My name is OMKAR
# <class 'str'>

# %%
a= int (input("First Number ="))
b = int (input ("Secound Number=  "))
print (" sum =" , a+b)
# Out:
# First Number =12
# Secound Number=  23
#  sum = 35
