# %%
number = [1, 2, 3, 4]
number.extend([5, 6, 7, 8])
print(number)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
number = [1, 2, 3, 4]
number.insert(2, 7)
print(number)
# Out:
# [1, 2, 7, 3, 4]

# %%
number = [1, 2, 3, 4]
number.append(5)
print(number)
# Out:
# [1, 2, 3, 4, 5]

# %%
number = [1, 2, 3, 4]
number.pop()
print(number)
# Out:
# [1, 2, 3]

# %%
number = [1, 2, 3, 4]
number.remove(2)
print(number)
# Out:
# [1, 3, 4]

# %%
number = [1, 2, 3, 4]
number.copy()
print(number)
# Out:
# [1, 2, 3, 4]

# %%
number = [1, 2, 3, 4]
max_value = max(number)
print(max_value)
# Out:
# 4

# %%
number = [1, 2, 3, 4]
min = min(number)
print(min)
# Out:
# 1

# %%
number = [1, 2, 3, 4]
number.sort(reverse=True)
print(number)
# Out:
# [4, 3, 2, 1]

# %%
number = [1, 2, 3, 4]
sum_value =sum(number)
print(sum_value)
# Out:
# 10
