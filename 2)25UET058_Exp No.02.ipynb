# %%
name = "welcome"
text = "welcome"
print(text[0:5])
print(text[0:6:2])
print(text[0:])
print(text[:6])
print(text[:-7])
print(text[3:6])
print(text[1:3])
print("Omkar " *4)
fname = "Omkar"
lname = "Patil"
print(fname+"   "+lname)
text="Welcome To DKTE"
print("Welcome"in text)
print("Welcome"not in text)
print("DKTE"not in text)
# Out:
# welco
# wlo
# welcome
# welcom
#
# com
# el
# Omkar Omkar Omkar Omkar
# Omkar   Patil
# True
# False
# False

# %%
a = "Python is easy"
print(a.replace("Python","Java"))
print(a)
b="prem shinde"
print(b.capitalize())
c="prem shinde"
print(c.split())
# Out:
# Java is easy
# Python is easy
# Prem shinde
# ['prem', 'shinde']
